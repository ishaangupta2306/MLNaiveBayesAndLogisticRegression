# %% [markdown]
# # Voting
#
# |Classifier| Accuracy|Precision|Recall|Area under ROC|
# |:--|--:|--:|--:|--:|
# |Naive Bayes (10 bins)|0.9862493±0.013296284|0.98434556±0.020986782|0.985±0.02|0.18729214|
# |Logistic Regression|0.9863831±0.016497372|1.0±0.0|0.96944445±0.036683496|0.9947449|

# %% [markdown]
# # Spam
#
# |Classifier| Accuracy|Precision|Recall|Area under ROC|
# |:--|--:|--:|--:|--:|
# |Naive Bayes (10 bins)|0.7067142±0.003688279|0.7636026±0.003101425|0.76920784±0.009568671|0.49727434|
# |Logistic Regression|0.70753056±0.0014711331|0.7305749±0.0012120218|0.84336436±0.00312121|0.73819494|

# %% [markdown]
# # Volcanoes
#
# |Classifier| Accuracy|Precision|Recall|Area under ROC|
# |:--|--:|--:|--:|--:|
# |Naive Bayes (10 bins)|0.61723053±0.015083462|0.45339337±0.0126613295|0.82229203±0.0418663|0.5003333|
# |Logistic Regression|0.83279455±0.008027922|0.76808566±0.015856154|0.70168877±0.021936433|0.8893386|

# %%
import matplotlib.pyplot as plt
Auc_values = [0.8861556, 0.88663256, 0.8893386, 0.8992871]
lambd = [0, .001, .01, .1]
plt.scatter(lambd, Auc_values)
plt.title("Volcanoes")
# Out:
# Text(0, 0.5, 'AUC')

# %%
import matplotlib.pyplot as plt
Auc_values = [0.73794717, 0.7379902, 0.73819494, 0.7376288]
lambd = [0, .001, .01, .1]
plt.scatter(lambd, Auc_values)
plt.title("Spam")
# Out:
# Text(0, 0.5, 'AUC')

# %%
import matplotlib.pyplot as plt
Auc_values = [0.994949, 0.99484694, 0.9947449, 0.99443877]
lambd = [0, .001, .01, .1]
plt.scatter(lambd, Auc_values)
plt.title("Voting")
# Out:
# Text(0, 0.5, 'AUC')
